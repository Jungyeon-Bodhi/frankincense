# %%
import WEAI_domain as domain
import WEAI_analysis as bd
import pandas as pd


# Please assign the file path of the cleaned dataset
file_path = 'data/dummy_cleaned.xlsx' 

# Please assign the file path for data analysis matrix
file_path2 = "data/tables.xlsx"

file_path3 = "data/tables_breakdown.xlsx"

# Please assign the file path for data analysis matrix
df = pd.read_excel(file_path)
df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# Run the domain analysis
domains = domain.Domain(df)
df = domains.domain_analysis()

# Run the weai analysis
weai = bd.WEAI(df, name='Overall')
weai.analysis(file_path2)
weai.breakdown_save({1:{"G1.02a":"Region"},2:{"G1.05":"Age Group"}}, file_path3)
# Out:
# Average difference in i_score: 0.20
# Ratio of female having equal or higher individual empowerment score than male: 0.00
# Ratio of female having lower individual empowerment score than male: 1.00
# The Gender Parity Index score is 0.80
# The Women's Empowerment in Agriculture Index is 0.53
# Average difference in i_score: 0.20
# Ratio of female having equal or higher individual empowerment score than male: 0.00
# Ratio of female having lower individual empowerment score than male: 1.00
# The Gender Parity Index score is 0.80
# The Women's Empowerment in Agriculture Index is 0.53
# Average difference in i_score: 0.20
# Ratio of female having equal or higher individual empowerment score than male: 0.00
# Ratio of female having lower individual empowerment score than male: 1.00
# The Gender Parity Index score is 0.80
# The Women's Empowerment in Agriculture Index is 0.53
# Average difference in i_score: 0.20
# Ratio of female having equal or higher individual empowerment score than male: 0.00
# Ratio of female having lower individual empowerment score than male: 1.00
# The Gender Parity Index score is 0.80
# The Women's Empowerment in Agriculture Index is 0.53
# Average difference in i_score: 0.20
# Ratio of female having equal or higher individual empowerment score than male: 0.00
# Ratio of female having lower individual empowerment score than male: 1.00
# The Gender Parity Index score is 0.80
# The Women's Empowerment in Agriculture Index is 0.53
# /var/folders/0j/3kbdg36x21z37qcc3fqxx_0m0000gn/T/ipykernel_30127/4162963404.py:16: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
import pandas as pd
df = pd.read_excel('data/dummy.xlsx')

# %%
list(df.columns)
# Out:
# ['start',
#  'end',
#  'G1.01. Household Identification',
#  'G1.02a. Household’s State',
#  'G1.02b. Household’s Region (Puntland)',
#  'G1.02c. Household’s Location (Nugaal)',
#  'G1.02c. Household’s Location (Bari)',
#  'G1.02b. Household’s Region (Jubaland)',
#  'G1.02c. Household’s Location (Gedo)',
#  'G1.02c. Household’s Location (Lower Juba)',
#  'G1.02b. Household’s Region (South West State)',
#  'G1.02c. Household’s Location (Bay)',
#  'G1.02c. Household’s Location (Lower Shabelle)',
#  'G1.02b. Household’s Region (Hirshabelle)',
#  'G1.02c. Household’s Location (Hiran)',
#  'G1.02c. Household’s Location (Middle Shabelle)',
#  'G1.02b. Household’s Region (Galmudug)',
#  'G1.02c. Household’s Location (Mudug)',
#  'G1.02c. Household’s Location (Galgaduud)',
#  'G1.02b. Household’s Region (Somaliland)',
#  'G1.02c. Household’s Location (Awdal)',
#  'G1.02c. Household’s Location (Woqooyi Galbeed)',
#  'G1.03. What is your name?',
#  'G1.04. What is your sex?',
#  'G1.05. Which age group do you belong to?',
#  'G1.06 What is your type of household?',
#  'G1.07. With whom do you take this survey?',
#  'G1.08a. Do you have difficulty seeing, even if wearing glasses?',
#  'G1.08b. Do you have difficulty hearing, even if using a hearing aid?',
#  'G1.08c. Do you have difficulty walking or climbing steps?',
#  'G1.08d. Do you have difficulty remembering or concentrating?',
#  'G1.08e. Do you have difficulty with self-care such as washing all over or dressing?',
#  'G1.08f. Using your usual (customary) language, do you have difficulty communicating, for example understanding or being understood?',
#  'G2.01.A. Did you yourself participate in Food crop farming in the past 12 months (that is, during the last [one/two] cropping seasons)?',
#  'G2.02.A. How much input did you have in making decisions about Food crop farming?',
#  'G2.03.A. How much input did you have in decisions on the use of income generated from Food crop farming?',
#  'G2.01.B. Did you yourself participate in Cash crop farming in the past 12 months (that is, during the last [one/two] cropping seasons)?',
#  'G2.02.B. How much input did you have in making decisions about Cash crop farming?',
#  'G2.03.B. How much input did you have in decisions on the use of income generated from Cash crop farming?',
#  'G2.01.C. Did you yourself participate in Livestock raising in the past 12 months (that is, during the last [one/two] cropping seasons)?',
#  'G2.02.C. How much input did you have in making decisions about Livestock raising?',
#  'G2.03.C. How much input did you have in decisions on the use of income generated from Livestock raising?',
#  'G2.01.D. Did you yourself participate in Non-farm economic activities in the past 12 months (that is, during the last [one/two] cropping seasons)?',
#  'G2.02.D. How much input did you have in making decisions about Non-farm economic activities?',
#  'G2.03.D. How much input did you have in decisions on the use of income generated from Non-farm economic activities?',
#  'G2.01.E. Did you yourself participate in Wage and salary employment in the past 12 months (that is, during the last [one/two] cropping seasons)?',
#  'G2.02.E. How much input did you have in making decisions about Wage and salary employment?',
#  'G2.03.E. How much input did you have in decisions on the use of income generated from Wage and salary employment?',
#  'G2.01.F. Did you yourself participate in Fishing or fishpond culture in the past 12 months (that is, during the last [one/two] cropping seasons)?',
#  'G2.02.F. How much input did you have in making decisions about Fishing or fishpond culture?',
#  'G2.03.F. How much input did you have in decisions on the use of income generated from Fishing or fishpond culture?',
#  'G3.01a.A. Does anyone in your household currently have any agricultural land?',
#  'G3.01b.A. How many of agricultural land does your household currently have?',
#  'G3.02.A. Who would you say owns most of the agricultural land?',
#  'G3.03.A. Who would you say can decide whether to sell agricultural land most of the time?',
#  'G3.04.A. Who would you say can decide whether to give away agricultural land most of the time?',
#  'G3.05.A. Who would you say can decide to mortgage or rent out agricultural land most of the time?',
#  'G3.06.A. Who contributes most to decisions regarding a new purchase of agricultural land?',
#  'G3.01a.B. Does anyone in your household currently have any large livestock?',
#  'G3.01b.B. How many of large livestock does your household currently have?',
#  'G3.02.B. Who would you say owns most of the large livestock?',
#  'G3.03.B. Who would you say can decide whether to sell large livestock most of the time?',
#  'G3.04.B. Who would you say can decide whether to give away large livestock most of the time?',
#  'G3.05.B. Who would you say can decide to mortgage or rent out large livestock most of the time?',
#  'G3.06.B. Who contributes most to decisions regarding a new purchase of large livestock?',
#  'G3.01a.C. Does anyone in your household currently have any small livestock ?',
#  'G3.01b.C. How many of small livestock does your household currently have?',
#  'G3.02.C. Who would you say owns most of the small livestock?',
#  'G3.03.C. Who would you say can decide whether to sell small livestock most of the time?',
#  'G3.04.C. Who would you say can decide whether to give away small livestock most of the time?',
#  'G3.05.C. Who would you say can decide to mortgage or rent out small livestock most of the time?',
#  'G3.06.C. Who contributes most to decisions regarding a new purchase of small livestock?',
#  'G3.01a.D. Does anyone in your household currently have any chickens, ducks, turkeys, and pigeons?',
#  'G3.01b.D. How many of chickens, ducks, turkeys, and pigeons does your household currently have?',
#  'G3.02.D. Who would you say owns most of the chickens, ducks, turkeys, and pigeons?',
#  'G3.03.D. Who would you say can decide whether to sell chickens, ducks, turkeys, and pigeons most of the time?',
#  'G3.04.D. Who would you say can decide whether to give away chickens, ducks, turkeys, and pigeons most of the time?',
#  'G3.05.D. Who would you say can decide to mortgage or rent out chickens, ducks, turkeys, and pigeons most of the time?',
#  'G3.06.D. Who contributes most to decisions regarding a new purchase of chickens, ducks, turkeys, and pigeons?',
#  'G3.01a.E. Does anyone in your household currently have any fish pond or fishing equipment?',
#  'G3.01b.E. How many of fish pond or fishing equipment does your household currently have?',
#  'G3.02.E. Who would you say owns most of the fish pond or fishing equipment?',
#  'G3.03.E. Who would you say can decide whether to sell fish pond or fishing equipment most of the time?',
#  'G3.04.E. Who would you say can decide whether to give away fish pond or fishing equipment most of the time?',
#  'G3.05.E. Who would you say can decide to mortgage or rent out fish pond or fishing equipment most of the time?',
#  'G3.06.E. Who contributes most to decisions regarding a new purchase of fish pond or fishing equipment?',
#  'G3.01a.F. Does anyone in your household currently have any farm equipment (non-mechanized)?',
#  'G3.01b.F. How many of farm equipment (non-mechanized) does your household currently have?',
#  'G3.02.F. Who would you say owns most of the farm equipment (non-mechanized)?',
#  'G3.03.F. Who would you say can decide whether to sell farm equipment (non-mechanized) most of the time?',
#  'G3.04.F. Who would you say can decide whether to give away farm equipment (non-mechanized) most of the time?',
#  'G3.05.F. Who would you say can decide to mortgage or rent out farm equipment (non-mechanized) most of the time?',
#  'G3.06.F. Who contributes most to decisions regarding a new purchase of farm equipment (non-mechanized)?',
#  'G3.01a.G. Does anyone in your household currently have any farm equipment (mechanized)?',
#  'G3.01b.G. How many of farm equipment (mechanized) does your household currently have?',
#  'G3.02.G. Who would you say owns most of the farm equipment (mechanized)?',
#  'G3.03.G. Who would you say can decide whether to sell farm equipment (mechanized) most of the time?',
#  'G3.04.G. Who would you say can decide whether to give away farm equipment (mechanized) most of the time?',
#  'G3.05.G. Who would you say can decide to mortgage or rent out farm equipment (mechanized) most of the time?',
#  'G3.06.G. Who contributes most to decisions regarding a new purchase of farm equipment (mechanized)?',
#  'G3.01a.H. Does anyone in your household currently have any non-farm business equipment?',
#  'G3.01b.H. How many of non-farm business equipment does your household currently have?',
#  'G3.02.H. Who would you say owns most of the non-farm business equipment?',
#  'G3.03.H. Who would you say can decide whether to sell non-farm business equipment most of the time?',
#  'G3.04.H. Who would you say can decide whether to give away non-farm business equipment most of the time?',
#  'G3.05.H. Who would you say can decide to mortgage or rent out non-farm business equipment most of the time?',
#  'G3.06.H. Who contributes most to decisions regarding a new purchase of non-farm business equipment?',
#  'G3.01a.I. Does anyone in your household currently have any house (and other structures)?',
#  'G3.01b.I. How many of house (and other structures) does your household currently have?',
#  'G3.02.I. Who would you say owns most of the house (and other structures)?',
#  'G3.03.I. Who would you say can decide whether to sell house (and other structures) most of the time?',
#  'G3.04.I. Who would you say can decide whether to give away house (and other structures) most of the time?',
#  'G3.05.I. Who would you say can decide to mortgage or rent out house (and other structures) most of the time?',
#  'G3.06.I. Who contributes most to decisions regarding a new purchase of house (and other structures)?',
#  'G3.01a.J. Does anyone in your household currently have any large consumer durables ?',
#  'G3.01b.J. How many of large consumer durables does your household currently have?',
#  'G3.02.J. Who would you say owns most of the large consumer durables?',
#  'G3.03.J. Who would you say can decide whether to sell large consumer durables most of the time?',
#  'G3.04.J. Who would you say can decide whether to give away large consumer durables most of the time?',
#  'G3.05.J. Who would you say can decide to mortgage or rent out large consumer durables most of the time?',
#  'G3.06.J. Who contributes most to decisions regarding a new purchase of large consumer durables?',
#  'G3.01a.K. Does anyone in your household currently have any small consumer durables?',
#  'G3.01b.K. How many of small consumer durables does your household currently have?',
#  'G3.02.K. Who would you say owns most of the small consumer durables?',
#  'G3.03.K. Who would you say can decide whether to sell small consumer durables most of the time?',
#  'G3.04.K. Who would you say can decide whether to give away small consumer durables most of the time?',
#  'G3.05.K. Who would you say can decide to mortgage or rent out small consumer durables most of the time?',
#  'G3.06.K. Who contributes most to decisions regarding a new purchase of small consumer durables?',
#  'G3.01a.L. Does anyone in your household currently have any cell phone?',
#  'G3.01b.L. How many of cell phone does your household currently have?',
#  'G3.02.L. Who would you say owns most of the cell phone?',
#  'G3.03.L. Who would you say can decide whether to sell cell phone most of the time?',
#  'G3.04.L. Who would you say can decide whether to give away cell phone most of the time?',
#  'G3.05.L. Who would you say can decide to mortgage or rent out cell phone most of the time?',
#  'G3.06.L. Who contributes most to decisions regarding a new purchase of cell phone?',
#  'G3.01a.M. Does anyone in your household currently have any other land not used for agricultural purposes ?',
#  'G3.01b.M. How many of other land not used for agricultural purposes does your household currently have?',
#  'G3.02.M. Who would you say owns most of the other land not used for agricultural purposes?',
#  'G3.03.M. Who would you say can decide whether to sell other land not used for agricultural purposes most of the time?',
#  'G3.04.M. Who would you say can decide whether to give away other land not used for agricultural purposes most of the time?',
#  'G3.05.M. Who would you say can decide to mortgage or rent out other land not used for agricultural purposes most of the time?',
#  'G3.06.M. Who contributes most to decisions regarding a new purchase of other land not used for agricultural purposes?',
#  'G3.01a.N. Does anyone in your household currently have any means of transportation?',
#  'G3.01b.N. How many of means of transportation does your household currently have?',
#  'G3.02.N. Who would you say owns most of the means of transportation?',
#  'G3.03.N. Who would you say can decide whether to sell means of transportation most of the time?',
#  'G3.04.N. Who would you say can decide whether to give away means of transportation most of the time?',
#  'G3.05.N. Who would you say can decide to mortgage or rent out means of transportation most of the time?',
#  'G3.06.N. Who contributes most to decisions regarding a new purchase of means of transportation?',
#  'G3.07.A. Has anyone in your household taken any loans or borrowed cash/in-kind from non-governmental organization (NGO) in the past 12 months?',
#  'G3.08.A. Who made the decision to borrow from non-governmental organization (NGO)?',
#  'G3.09.A. Who makes the decision about what to do with the money/ item borrowed from non-governmental organization (NGO)?',
#  'G3.07.B. Has anyone in your household taken any loans or borrowed cash/in-kind from informal lender in the past 12 months?',
#  'G3.08.B. Who made the decision to borrow from informal lender?',
#  'G3.09.B. Who makes the decision about what to do with the money/ item borrowed from informal lender?',
#  'G3.07.C. Has anyone in your household taken any loans or borrowed cash/in-kind from formal lender in the past 12 months?',
#  'G3.08.C. Who made the decision to borrow from formal lender?',
#  'G3.09.C. Who makes the decision about what to do with the money/ item borrowed from formal lender?',
#  'G3.07.D. Has anyone in your household taken any loans or borrowed cash/in-kind from friends or relatives in the past 12 months?',
#  'G3.08.D. Who made the decision to borrow from friends or relatives?',
#  'G3.09.D. Who makes the decision about what to do with the money/ item borrowed from friends or relatives?',
#  'G3.07.E. Has anyone in your household taken any loans or borrowed cash/in-kind from group-based micro-finance or lending including VSLAs/SACCOs/merry-go-rounds in the past 12 months?',
#  'G3.08.E. Who made the decision to borrow from group-based micro-finance or lending?',
#  'G3.09.E. Who makes the decision about what to do with the money/ item borrowed from group-based micro-finance or lending?',
#  'G4.01. Do you feel comfortable speaking up in public to help decide on infrastructure (like small wells, roads, water supplies) to be built in your community?',
#  'G4.02. Do you feel comfortable speaking up in public to ensure proper payment of wages for public works or other similar programs?',
#  'G4.03. Do you feel comfortable speaking up in public to protest the misbehavior of authorities or elected officials?',
#  'G4.04.A. Is there an agricultural / livestock/ fisheries producer’s group in your community?',
#  'G4.05.A. Are you an active member of this agricultural / livestock/ fisheries producer’s group?',
#  'G4.04.B. Is there a water users’ group in your community?',
#  'G4.05.B. Are you an active member of this water users’ group?',
#  'G4.04.C. Is there a forest users’ group in your community?',
#  'G4.05.C. Are you an active member of this forest users’ group?',
#  'G4.04.D. Is there a credit or micro-finance group in your community?',
#  'G4.05.D. Are you an active member of this credit or micro-finance group?',
#  'G4.04.E. Is there a mutual help or insurance group in your community?',
#  'G4.05.E. Are you an active member of this mutual help or insurance group?',
#  'G4.04.F. Is there a trade and business association group in your community?',
#  'G4.05.F. Are you an active member of this trade and business association group?',
#  'G4.04.G. Is there a civic or charitable group in your community?',
#  'G4.05.G. Are you an active member of this civic or charitable group?',
#  'G4.04.H. Is there a local government group in your community?',
#  'G4.05.H. Are you an active member of this local government group?',
#  'G4.04.I. Is there a religious group in your community?',
#  'G4.05.I. Are you an active member of this religious group?',
#  'G4.04.J. Is there an other women’s group in your community?',
#  "G4.05.J. Are you an active member of this other women's group?",
#  'G4.04.K. are there any other groups in your community?',
#  'G4.04.K.o. Please specify the name of this group',
#  'G4.05.K. Are you an active member of this group?',
#  'G5.01.A. When decisions are made regarding getting inputs for agricultural production who is it that normally takes the decision?',
#  'G5.01.B. When decisions are made regarding the types of crops to grow who is it that normally takes the decision?',
#  'G5.01.C. When decisions are made regarding taking crops to the market (or not) who is it that normally takes the decision?',
#  'G5.01.D. When decisions are made regarding livestock raising who is it that normally takes the decision?',
#  'G5.01.E. When decisions are made regarding your own wage or salary employment who is it that normally takes the decision?',
#  'G5.01.F. When decisions are made regarding major household expenditures who is it that normally takes the decision?',
#  'G5.01.G. When decisions are made regarding minor household expenditures who is it that normally takes the decision?',
#  'G5.02.A. To what extent do you feel you can make your own personal decisions regarding getting inputs for agricultural production if you want(ed) to?',
#  'G5.03.A. My actions in getting inputs for agricultural production are partly because I will get in trouble with someone if I act differently',
#  'G5.04.A. Regarding getting inputs for agricultural production I do what I do so others don’t think poorly of me',
#  'G5.05.A. Regarding getting inputs for agricultural production I do what I do because I personally think it is the right thing to do.',
#  'G5.02.B. To what extent do you feel you can make your own personal decisions regarding the types of crops to grow if you want(ed) to?',
#  'G5.03.B. My actions in the types of crops to grow for agricultural production are partly because I will get in trouble with someone if I act differently',
#  'G5.04.B. Regarding the types of crops to grow for agricultural production I do what I do so others don’t think poorly of me',
#  'G5.05.B. Regarding the types of crops to grow for agricultural production I do what I do because I personally think it is the right thing to do.',
#  'G5.02.C. To what extent do you feel you can make your own personal decisions regarding taking crops to the market (or not) if you want(ed) to?',
#  'G5.03.C. My actions in taking crops to the market (or not) are partly because I will get in trouble with someone if I act differently',
#  'G5.04.C. Regarding taking crops to the market (or not) I do what I do so others don’t think poorly of me.',
#  'G5.05.C. Regarding taking crops to the market (or not) I do what I do because I personally think it is the right thing to do.',
#  'G5.02.D. To what extent do you feel you can make your own personal decisions regarding livestock raising if you want(ed) to?',
#  'G5.03.D. My actions in livestock raising are partly because I will get in trouble with someone if I act differently',
#  'G5.04.D. Regarding livestock raising I do what I do so others don’t think poorly of me.',
#  'G5.05.D. Regarding livestock raising I do what I do because I personally think it is the right thing to do.',
#  'G5.02.E. To what extent do you feel you can make your own personal decisions regarding your own wage or salary employment if you want(ed) to?',
#  'G5.02.F. To what extent do you feel you can make your own personal decisions regarding major household expenditures if you want(ed) to?',
#  'G5.02.G. To what extent do you feel you can make your own personal decisions regarding minor household expenditures if you want(ed) to?',
#  "G6.01. Please use this link's format and upload it here:  https://drive.google.com/file/d/1ey-2_ihjlxAVM1dPnumW1s7BGU7lrrRj/view",
#  "G6.01. Please use this link's format and upload it here:  https://drive.google.com/file/d/1ey-2_ihjlxAVM1dPnumW1s7BGU7lrrRj/view_URL",
#  'G6.01.A1. Sleeping and resting (primary)',
#  'G6.01.A2. Sleeping and resting (secondary)',
#  'G6.01.B1. Eating and drinking (primary)',
#  'G6.01.B2. Eating and drinking (secondary)',
#  'G6.01.C1. Personal care (primary)',
#  'G6.01.C2. Personal care (secondary)',
#  'G6.01.D1. School (also homework) (primary)',
#  'G6.01.D2 School (also homework) (secondary)',
#  'G6.01.E1. Work as employed (primary)',
#  'G6.01.E2. Work as employed (secondary)',
#  'G6.01.F1. Own business work (primary)',
#  'G6.01.F2. Own business work (secondary)',
#  'G6.01.G1. Farming/livestock/fishing (primary)',
#  'G6.01.G2. Farming/livestock/fishing (secondary)',
#  'G6.01.H1. Shopping/getting services (such as health services) (primary)',
#  'G6.01.H2. Shopping/getting services (such as health services) (secondary)',
#  'G6.01.I1. Weaving/sewing/textile care (primary)',
#  'G6.01.I2. Weaving/sewing/textile care (secondary)',
#  'G6.01.J1. Cooking (primary)',
#  'G6.01.J2. Cooking (secondary)',
#  'G6.01.K1. Domestic work (primary)',
#  'G6.01.K2. Domestic work (secondary)',
#  'G6.01.L1. Care for children/adults/elderly (primary)',
#  'G6.01.L2. Care for children/adults/elderly (secondary)',
#  'G6.01.M1. Traveling/commuting (primary)',
#  'G6.01.M2. Traveling/commuting (secondary)',
#  'G6.01.N1. Watching TV/listening to radio/reading (primary)',
#  'G6.01.N2. Watching TV/listening to radio/reading (secondary)',
#  'G6.01.O1. Exercising (primary)',
#  'G6.01.O2. Exercising (secondary)',
#  'G6.01.P1. Social activities and hobbies (primary)',
#  'G6.01.P2. Social activities and hobbies (secondary)',
#  'G6.01.Q1. Religious activities (primary)',
#  'G6.01.Q2. Religious activities (secondary)',
#  'G6.01.R1. Other (If exists) (primary)',
#  'G6.01.R1.0 If other, please specify the name of activity',
#  'G6.01.R2. Other (If exists) (secondary)',
#  'G6.01.R2.0 If other, please specify the name of activity',
#  'G6.02. How satisfied are you with your available time for leisure activities like visiting neighbors, watching TV, listening to the radio, seeing movies or doing sports?',
#  'G1.05. OUTCOME OF INTERVIEW',
#  '_id',
#  '_uuid',
#  '_submission_time',
#  '_validation_status',
#  '_notes',
#  '_status',
#  '_submitted_by',
#  '__version__',
#  '_tags',
#  '_index']

# %%
 "G6.01-i",
 "G6.01-ii",
 'G6.01.A1',
 'G6.01.A2',
 'G6.01.B1',
 'G6.01.B2',
 'G6.01.C1',
 'G6.01.C2',
 'G6.01.D1',
 'G6.01.D2',
 'G6.01.E1',
 'G6.01.E2',
 'G6.01.F1',
 'G6.01.F2',
 'G6.01.G1',
 'G6.01.G2',
 'G6.01.H1',
 'G6.01.H2',
 'G6.01.I1',
 'G6.01.I2',
 'G6.01.J1',
 'G6.01.J2',
 'G6.01.K1',
 'G6.01.K2',
 'G6.01.L1',
 'G6.01.L2',
 'G6.01.M1',
 'G6.01.M2',
 'G6.01.N1',
 'G6.01.N2',
 'G6.01.O1',
 'G6.01.O2',
 'G6.01.P1',
 'G6.01.P2',
 'G6.01.Q1',
 'G6.01.Q2',
 'G6.01.R1',
 'G6.01.R1.0',
 'G6.01.R2',
 'G6.01.R2.0',

# %%
 'G6.01.A1',
 'G6.01.B1',
 'G6.01.C1',
 'G6.01.D1',
 'G6.01.E1',
 'G6.01.F1',
 'G6.01.G1',
 'G6.01.H1',
 'G6.01.I1',
 'G6.01.J1',
 'G6.01.K1',
 'G6.01.L1',
 'G6.01.M1',
 'G6.01.N1',
 'G6.01.O1',
 'G6.01.P1',
 'G6.01.Q1'

# %%
domains = Domain(df)

# %%
df = domains.domain_analysis()

# %%
weai = WEAI(df, name='Overall')

# %%
weai.individual_empowerment_score()

# %%
weai.gender_parity_index()

# %%
weai.weai()

# %%
weai.weai_table()

# %%
weai.domain_table()

# %%
weai.save_tables(file_path = 'tables.xlsx')

# %%
df
